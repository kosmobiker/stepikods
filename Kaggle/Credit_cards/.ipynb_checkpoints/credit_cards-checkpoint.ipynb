# %%
import numpy as np
import pandas as pd
import seaborn as sns
from tqdm import tqdm_notebook

# %matplotlib inline
from matplotlib import pyplot as plt
plt.style.use(['seaborn-darkgrid'])

from sklearn import metrics
from sklearn.metrics import davies_bouldin_score
from sklearn.cluster import KMeans, AgglomerativeClustering, SpectralClustering, \
                        AffinityPropagation, MeanShift, DBSCAN, OPTICS
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv('../../data/CC GENERAL.csv')

# %% [markdown]
# Following is the Data Dictionary for Credit Card dataset :-
#
# - CUSTID : Identification of Credit Card holder (Categorical)
# - BALANCE : Balance amount left in their account to make purchases (
# - BALANCEFREQUENCY : How frequently the Balance is updated, score between 0 and 1 (1 = frequently updated, 0 = not frequently updated)
# - PURCHASES : Amount of purchases made from account
# - ONEOFFPURCHASES : Maximum purchase amount done in one-go
# - INSTALLMENTSPURCHASES : Amount of purchase done in installment
# - CASHADVANCE : Cash in advance given by the user
# - PURCHASESFREQUENCY : How frequently the Purchases are being made, score between 0 and 1 (1 = frequently purchased, 0 = not frequently purchased)
# - ONEOFFPURCHASESFREQUENCY : How frequently Purchases are happening in one-go (1 = frequently purchased, 0 = not frequently purchased)
# - PURCHASESINSTALLMENTSFREQUENCY : How frequently purchases in installments are being done (1 = frequently done, 0 = not frequently done)
# - CASHADVANCEFREQUENCY : How frequently the cash in advance being paid
# - CASHADVANCETRX : Number of Transactions made with "Cash in Advanced"
# - PURCHASESTRX : Number of purchase transactions made
# - CREDITLIMIT : Limit of Credit Card for user
# - PAYMENTS : Amount of Payment done by user
# - MINIMUM_PAYMENTS : Minimum amount of payments made by user
# - PRCFULLPAYMENT : Percent of full payment paid by user
# - TENURE : Tenure of credit card service for user

# %%
data.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
data = data.drop('CUST_ID', axis=1)

# %% [markdown]
# Number of NA values in dataset

# %%
data.isna().sum()
# Out:
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
data['CREDIT_LIMIT'] = data['CREDIT_LIMIT'].fillna(data['CREDIT_LIMIT'].mean())

# %%
data['MINIMUM_PAYMENTS'] = data['MINIMUM_PAYMENTS'].fillna(data['MINIMUM_PAYMENTS'].mean())

# %% [markdown]
# Visual analysis

# %%
data.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %%
data.corr().abs().unstack().sort_values(kind="quicksort", ascending=False).head(30)
# Out:
# TENURE                            TENURE                              1.000000
# PRC_FULL_PAYMENT                  PRC_FULL_PAYMENT                    1.000000
# BALANCE_FREQUENCY                 BALANCE_FREQUENCY                   1.000000
# PURCHASES                         PURCHASES                           1.000000
# ONEOFF_PURCHASES                  ONEOFF_PURCHASES                    1.000000
# INSTALLMENTS_PURCHASES            INSTALLMENTS_PURCHASES              1.000000
# CASH_ADVANCE                      CASH_ADVANCE                        1.000000
# PURCHASES_FREQUENCY               PURCHASES_FREQUENCY                 1.000000
# ONEOFF_PURCHASES_FREQUENCY        ONEOFF_PURCHASES_FREQUENCY          1.000000
# CASH_ADVANCE_FREQUENCY            CASH_ADVANCE_FREQUENCY              1.000000
# CASH_ADVANCE_TRX                  CASH_ADVANCE_TRX                    1.000000
# PURCHASES_TRX                     PURCHASES_TRX                       1.000000
# ...

# %%
data = data.drop(['ONEOFF_PURCHASES', 'PURCHASES_INSTALLMENTS_FREQUENCY', 'CASH_ADVANCE_FREQUENCY'], axis=1)

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(data)

# %%
pca = PCA(n_components = 3)
X_pca = pca.fit_transform(X_scaled)

# %%
X_pca.shape
# Out:
# (8950, 3)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.27207297, 0.19388138, 0.0917482 ])

# %%
kmeans = KMeans(n_init=100)

n_classes = 20

inertia = []
for k in tqdm_notebook(range(1, n_classes + 1)):
    kmeans = KMeans(n_clusters=k, n_init=100, n_jobs=-1).fit(X_scaled)
    inertia.append(np.sqrt(kmeans.inertia_))

plt.plot(range(1, n_classes + 1), inertia, marker='s');
plt.xlabel('$k$')
plt.ylabel('$J(C_k)$');

# %%
algorithms = []
X = X_pca
n_classes = 3

algorithms.append(KMeans(n_clusters=n_classes, n_init=100, n_jobs=-1))
algorithms.append(AgglomerativeClustering(n_clusters=n_classes, linkage='ward'))
algorithms.append(DBSCAN())
algorithms.append(OPTICS())


df = []
for algo in algorithms:
    algo.fit(X)
    df.append(({"silhouette" : metrics.silhouette_score(X, algo.labels_, metric='euclidean'),
                "calinski_harabasz" : metrics.calinski_harabasz_score(X, algo.labels_),
                "davies_bouldin" : davies_bouldin_score(X, algo.labels_)})) 

    
results = pd.DataFrame(df, columns=['silhouette', 'calinski_harabasz', 'davies_bouldin'],
                       index=['KMeans', 'AgglomerativeClustering', 
                              'DBSCAN', 'OPTICS'])
results
# Out:
#                          silhouette  calinski_harabasz  davies_bouldin
# KMeans                     0.406260        3745.025470        0.970951
# AgglomerativeClustering    0.447086        3000.530353        0.981564
# DBSCAN                     0.120751         221.296643        2.339101
# OPTICS                    -0.430160           8.393742        1.395546

# %%
fig, axs = plt.subplots(ncols=2, figsize=(16, 6))
ac = AgglomerativeClustering(n_clusters=n_classes, linkage='ward').fit(X)
axs[0].scatter(X_pca[:, 0], X_pca[:, 1]);
axs[1].scatter(X_pca[:, 0], X_pca[:, 1], c=ac.labels_, s=20,  cmap='viridis');

# %%
clusters = pd.Series(ac.labels_, name='CLUSTER')
data = pd.read_csv('CC GENERAL.csv').join(clusters)

# %%
data.groupby(['CLUSTER']).median()
# Out:
#              BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# CLUSTER
# 0         559.750373                1.0     313.89              0.00
# 1        2598.580674                1.0    4342.07           2447.99
# 2        5312.083416                1.0     208.51              0.00
#
#          INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# CLUSTER
# 0                         69.49      0.000000             0.416667
# 1                       1526.64      0.000000             1.000000
# 2                          0.00   4292.337621             0.166667
#
#          ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# CLUSTER
# 0                              0.00                          0.166667
# 1                              0.75                          1.000000
# 2                              0.00                          0.000000
#
#          CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  \
# CLUSTER
# ...

# %%
data.groupby(['CLUSTER']).count()
# Out:
#          CUST_ID  BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# CLUSTER
# 0           7483     7483               7483       7483              7483
# 1            623      623                623        623               623
# 2            844      844                844        844               844
#
#          INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# CLUSTER
# 0                          7483          7483                 7483
# 1                           623           623                  623
# 2                           844           844                  844
#
#          ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# CLUSTER
# 0                              7483                              7483
# 1                               623                               623
# 2                               844                               844
#
#          CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  \
# CLUSTER
# ...
